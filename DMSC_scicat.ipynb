# %%
# !export HTTP_PROXY="http://172.18.12.30:8123"
# !export HTTPS_PROXY="http://172.18.12.30:8123"
# !pip install scicat

# %%
import scicat

# %%
import os
import os.path
os.environ['HTTP_PROXY'] = "http://172.18.12.30:8123"
os.environ['HTTPS_PROXY'] = "http://172.18.12.30:8123"

# %%
import scicat
result=scicat.search("taylor",1)
print(result[0]["sourceFolder"])
# Out:
# 1 result found!
# /nfs/groups/beamlines/dmsc/Mar25930

# %%
os.listdir("/home/jovyan/beamlines/dmsc/Mar25930")
# Out:
# ['MAR19717_ICPdebug.txt',
#  'MAR20009_ICPevent.txt',
#  'MAR25968.nxs',
#  'MAR19992_ICPevent.txt',
#  'MAR20006_ICPdebug.txt',
#  'MAR19718_ICPevent.txt',
#  'MAR19993_ICPevent.txt',
#  'MAR20003.raw',
#  'MAR25961.nxs',
#  'MAR19994.raw',
#  'MAR19982.log',
#  'MAR20015.log',
#  'MAR20007_ICPdebug.txt',
#  'MAR19985.log',
#  'MAR20012.log',
#  'MAR20004.raw',
#  'MAR20008_ICPevent.txt',
#  'MAR25966.nxs',
#  'MAR19993.raw',
#  'MAR20005_ICPdebug.txt',
#  'MAR19986_Status.txt',
#  'MAR20016_Status.txt',
#  'MAR25953.nxs',
#  'MAR19990_Status.txt',
#  'MAR20000_Status.txt',
#  'MAR19991_ICPevent.txt',
#  'MAR25954.nxs',
#  'MAR20004_ICPdebug.txt',
#  'MAR19990_ICPevent.txt',
#  'MAR20007_Status.txt',
#  'MAR19997_Status.txt',
#  'MAR25930.nxs',
#  'MAR20011_Status.txt',
#  'MAR19981_Status.txt',
#  'MAR19995_ICPevent.txt',
#  'MAR25937.nxs',
#  'MAR20001_ICPdebug.txt',
#  'MAR25945.nxs',
#  'MAR19994_ICPevent.txt',
#  'MAR20000_ICPdebug.txt',
#  'MAR25939.nxs',
#  'MAR25942.nxs',
# ...

# %%
import h5py
f = h5py.File('/home/jovyan/beamlines/dmsc/Mar25930/MAR25968.nxs', 'r')
title=f['/raw_data_1/title']
print(title[()])
# Out:
# [b'Bi4Fe5O13F - 66meV 350Hz Gd - T=5K']
